# %% [markdown]
# **Problem statement:**
#
# Continuous bag of words (cbow) word2vec word embedding work is that it tends to predict the probability of a word given a context. A context may be a single word or a group of words. But for simplicity, I will take a single context word and try to predict a single target word.
#
# The purpose of this assignment is to be able to create a word embedding for the  given data set.
#
# **Data set :** w2v.txt

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Embedding,Dense
from scipy import spatial

# %% [markdown]
# ### Function Definations

# %%
# Finding the maximum length of an array required to include all sentences. Vocabulary size, in order to create the 
# same size inputs by padding with zeros

def get_max_vocabulary_size(encoded_line_words):
    max_voc_size = 0
    max_integer_index = 0
    for l in encoded_line_words:
        if (len(l) > 0) and (np.argmax(l) > max_integer_index):
            max_integer_index = l[np.argmax(l)]
        if max_voc_size < len(l):
            max_voc_size = len(l)
    return max_voc_size

# %%
# Creating a new list with the targets for the words with window size as window_size. 
# Only positive window size is taken into consideration

def map_target(context, window_size):
    if window_size < 0:
        print("Only Positive window sie is expected.")
        return;
    target = context[window_size:]
    m = 10
    i = 0
    while i < window_size :
        target = np.append(target, [0])
        i = i + 1
    return np.array(target)

# %%
# Creating array of targets using the map_target function

def map_all_targets(context_list, window_size):
    targets = []
    for context in context_list:
        target_row = map_target(context, window_size)
        targets.append(np.array(target_row))
    return targets

# %%
def pad_sequences_words(file_lines_words, maxlen):
    padded_word = []
    for line_word in file_lines_words:
        blank_word_index = len(line_word)
        while blank_word_index < maxlen:
            line_word.append("")
            padded_word.append(line_word)
            blank_word_index = blank_word_index + 1

# %%
# Read the text file and return a dict with lines of the file, words in line, 
# encoded words in line, padded context words and targets

def read_txt(txt_file, window_size):
    file_lines = []
    file_lines_words = []
    encoded_file_lines_words = []
    target_file_lines_words = []
    with open(txt_file, 'r', encoding="utf-8") as file:
        try:
            for line in file:
                try:
                    line = line.strip()
                    if line!="":
                        file_lines.append(line)
                        allWords = line.split(" ")
                        file_words = []
                        encoded_file_words = []
                        try:
                            for word in allWords:
                                if word.strip()!="" and len(allWords)>1:
                                    file_words.append(word.strip())  
                                    encoded_file_words.append(one_hot(word.strip(),len(allWords))[0])
                        except Exception as E:
                            print ("got An exception 1: ", E)
                            pass  
                        file_lines_words.append(file_words)
                        encoded_file_lines_words.append(encoded_file_words)
                except Exception as E:
                    print ("got An exception 2: ", E)
                    pass         
        except Exception as E:
            print ("got An exception 3: ", E)
            pass  
        
    max_integer_index = get_max_vocabulary_size(encoded_file_lines_words)
    padded_context = pad_sequences(encoded_file_lines_words, maxlen = max_integer_index, padding='post')
    padded_context_words = pad_sequences_words(file_lines_words, maxlen = max_integer_index)
    targets = np.array(map_all_targets(context_list=padded_context, window_size=window_size))
    return {'lines':file_lines, 'line_words':file_lines_words, 'encoded_line_words':encoded_file_lines_words, 
            'padded_context':padded_context, 'targets':targets, 'vocab_size': max_integer_index}

# %%
# All the parameters calculation and constants are being set using this function. 
# Any changes to the parameters should be mafe here to avoid execution errors.

def parameters(context):
    INPUT_DIM = max([max(ctx) for ctx in context])+1
    OUTPUT_DIM = 8
    INPUT_LENGTH = len(context[0])
    EPOCHS = 1000
    VERBOSE = 1
    LOSS = 'categorical_crossentropy'
    ACTIVATION = 'softmax'
    OPTIMIZER = 'adam'
    MATRIX = ['accuracy']
    BESTMODEL = 'embeddings.h5'
    return (INPUT_DIM, OUTPUT_DIM, INPUT_LENGTH, EPOCHS, VERBOSE, LOSS, ACTIVATION, OPTIMIZER, MATRIX, BESTMODEL)

# %%
file_details = read_txt("w2v.txt", window_size=1)

# %%
context = file_details['padded_context']
targets = file_details['targets']

# %%
# Confirming that the shapes of context and targets are same

context.shape, targets.shape
# Out:
# ((13, 178), (13, 178))

# %%
# Unit testing the context and it's relavent target. Change the index between 0 to 12 to check the pair

index = 1
context[index], targets[index]
# Out:
# (array([ 14, 154, 117, 137,   3,  52, 152,  82,  95, 120,  14,  39,  37,
#          14, 108, 117,  14,  25,  27, 103, 102,  15,  78, 103,  14, 119,
#         117,  52, 169, 128, 173, 151, 138, 175,  70,  14,  15, 117, 101,
#         136,  88, 120,  14,  79,   5,  44, 101,  48,  61,  90, 120, 129,
#          87, 117, 166,  14, 153, 151, 154,  39,  70,  30,  14,  85, 141,
#         117,   3,  77, 120,  83, 108, 147, 129,  86, 133, 102,   3, 101,
#          48,  61, 156,  58,  83,  34, 120,   3, 173, 108, 175, 120, 109,
#           3, 176,  93,  52, 152, 117, 176,   3,  27, 102, 120, 109,   3,
#         176,  93,  52, 152, 117, 111,  83, 120, 109,  14,   3, 152, 103,
#         173, 108, 176, 148, 120,  67,  48,  61, 118, 107,  27, 148, 134,
#         120,  14,  46,  70, 142, 121,  12, 130,  74,  70, 166,  77, 117,
#          85,  62, 124, 150,  14, 149, 100,  28,  27, 108,  79, 129,  92,
#         139, 108,  88,  37,  35,  21,  55, 125,  73, 138, 171,  14,  29,
#         117, 152,  27,  14, 130,  19, 117,  14, 103], dtype=int32),
#  array([154, 117, 137,   3,  52, 152,  82,  95, 120,  14,  39,  37,  14,
#         108, 117,  14,  25,  27, 103, 102,  15,  78, 103,  14, 119, 117,
#          52, 169, 128, 173, 151, 138, 175,  70,  14,  15, 117, 101, 136,
#          88, 120,  14,  79,   5,  44, 101,  48,  61,  90, 120, 129,  87,
#         117, 166,  14, 153, 151, 154,  39,  70,  30,  14,  85, 141, 117,
#           3,  77, 120,  83, 108, 147, 129,  86, 133, 102,   3, 101,  48,
#          61, 156,  58,  83,  34, 120,   3, 173, 108, 175, 120, 109,   3,
#         176,  93,  52, 152, 117, 176,   3,  27, 102, 120, 109,   3, 176,
#          93,  52, 152, 117, 111,  83, 120, 109,  14,   3, 152, 103, 173,
#         108, 176, 148, 120,  67,  48,  61, 118, 107,  27, 148, 134, 120,
#          14,  46,  70, 142, 121,  12, 130,  74,  70, 166,  77, 117,  85,
#          62, 124, 150,  14, 149, 100,  28,  27, 108,  79, 129,  92, 139,
#         108,  88,  37,  35,  21,  55, 125,  73, 138, 171,  14,  29, 117,
#         152,  27,  14, 130,  19, 117,  14, 103,   0]))

# %%
INPUT_DIM, OUTPUT_DIM, INPUT_LENGTH, EPOCHS, VERBOSE, LOSS, ACTIVATION, OPTIMIZER, MATRIX, BESTMODEL = \
parameters(context)

# %%
# Calback array to save the best model. Best model is decided on the basis of accuracy.

callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath=BESTMODEL, monitor = MATRIX[0], 
                                                            save_best_only=True)]

# %%
# Creating the sequential model with Embedding layer with output dimention of 8
# The weights of the first layers will be used as the word embedding
# these weights will later be used to calculate the distance between the words.
# least distant words are most related and vice versa

model = Sequential()
embedding_layer = Embedding(input_dim=INPUT_DIM, output_dim=OUTPUT_DIM, input_length=INPUT_LENGTH)
model.add(embedding_layer)
model.add(Flatten())

# A softmax activation is used.

model.add(Dense(INPUT_LENGTH, activation = ACTIVATION))

model.compile(optimizer = OPTIMIZER, loss=LOSS, metrics = MATRIX)
# Out:
# 2022-04-05 20:31:56.224629: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Summary of the model 

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 178, 8)            1416
# _________________________________________________________________
# flatten (Flatten)            (None, 1424)              0
# _________________________________________________________________
# dense (Dense)                (None, 178)               253650
# =================================================================
# Total params: 255,066
# Trainable params: 255,066
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Training cell. History variable contains all the loss and accuracy at each step.

history = model.fit(context, targets, epochs = EPOCHS, verbose=VERBOSE, callbacks=callback_list)
# Out:
# Epoch 1/1000
# 2022-04-05 20:31:56.491479: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 1/1 [==============================] - 1s 561ms/step - loss: 10044.0527 - accuracy: 0.0000e+00
# Epoch 2/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 10029.7588 - accuracy: 0.0000e+00
# Epoch 3/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 10015.4512 - accuracy: 0.0000e+00
# Epoch 4/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 10000.9014 - accuracy: 0.0000e+00
# Epoch 5/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 9986.0293 - accuracy: 0.0000e+00
# Epoch 6/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 9970.8076 - accuracy: 0.0000e+00
# Epoch 7/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 9955.2412 - accuracy: 0.0000e+00
# Epoch 8/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 9939.3408 - accuracy: 0.0000e+00
# Epoch 9/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9923.1338 - accuracy: 0.0000e+00
# Epoch 10/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 9906.6553 - accuracy: 0.0000e+00
# Epoch 11/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9889.9492 - accuracy: 0.0000e+00
# Epoch 12/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 9873.0664 - accuracy: 0.0000e+00
# Epoch 13/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 9856.0693 - accuracy: 0.0000e+00
# Epoch 14/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 9839.0225 - accuracy: 0.0000e+00
# Epoch 15/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 9822.0010 - accuracy: 0.0000e+00
# Epoch 16/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 9805.0850 - accuracy: 0.0000e+00
# Epoch 17/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9788.3604 - accuracy: 0.0000e+00
# Epoch 18/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 9771.9199 - accuracy: 0.0769
# Epoch 19/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 9755.8633 - accuracy: 0.0769
# Epoch 20/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9740.3018 - accuracy: 0.0769
# Epoch 21/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 9725.3477 - accuracy: 0.0769
# Epoch 22/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9711.1289 - accuracy: 0.0769
# Epoch 23/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 9697.7734 - accuracy: 0.0769
# Epoch 24/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9685.4180 - accuracy: 0.0769
# Epoch 25/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9674.2070 - accuracy: 0.0769
# Epoch 26/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 9664.2881 - accuracy: 0.0769
# Epoch 27/1000
# 1/1 [==============================] - ETA: 0s - loss: 9655.8135 - accuracy: 0.076 - 0s 11ms/step - loss: 9655.8135 - accuracy: 0.0769
# Epoch 28/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 9648.9414 - accuracy: 0.0769
# Epoch 29/1000
# 1/1 [==============================] - ETA: 0s - loss: 9643.8281 - accuracy: 0.076 - 0s 15ms/step - loss: 9643.8281 - accuracy: 0.0769
# Epoch 30/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 9640.6309 - accuracy: 0.0769
# Epoch 31/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 9639.5107 - accuracy: 0.0769
# Epoch 32/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 9640.6211 - accuracy: 0.0769
# Epoch 33/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9644.1152 - accuracy: 0.0769
# Epoch 34/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 9650.1387 - accuracy: 0.0769
# Epoch 35/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 9658.8301 - accuracy: 0.0769
# Epoch 36/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9670.3242 - accuracy: 0.0769
# Epoch 37/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9684.7402 - accuracy: 0.0769
# Epoch 38/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 9702.1875 - accuracy: 0.0769
# Epoch 39/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 9722.7695 - accuracy: 0.0769
# Epoch 40/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9746.5684 - accuracy: 0.0769
# Epoch 41/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 9773.6543 - accuracy: 0.0769
# Epoch 42/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 9804.0869 - accuracy: 0.0769
# Epoch 43/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 9837.9082 - accuracy: 0.0769
# Epoch 44/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9875.1475 - accuracy: 0.0769
# Epoch 45/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 9915.8223 - accuracy: 0.0769
# Epoch 46/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 9959.9336 - accuracy: 0.0769
# Epoch 47/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 10007.4756 - accuracy: 0.0769
# Epoch 48/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 10058.4336 - accuracy: 0.0769
# Epoch 49/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 10112.7803 - accuracy: 0.0769
# Epoch 50/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 10170.4844 - accuracy: 0.0769
# Epoch 51/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 10231.5117 - accuracy: 0.0769
# Epoch 52/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 10295.8242 - accuracy: 0.0769
# Epoch 53/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 10363.3799 - accuracy: 0.0769
# Epoch 54/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 10434.1387 - accuracy: 0.0769
# Epoch 55/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 10508.0605 - accuracy: 0.0769
# Epoch 56/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 10585.1084 - accuracy: 0.0769
# Epoch 57/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 10665.2451 - accuracy: 0.0769
# Epoch 58/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 10748.4414 - accuracy: 0.0769
# Epoch 59/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 10834.6670 - accuracy: 0.0769
# Epoch 60/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 10923.8975 - accuracy: 0.0769
# Epoch 61/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 11016.1152 - accuracy: 0.0769
# Epoch 62/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 11111.3027 - accuracy: 0.0769
# Epoch 63/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 11209.4463 - accuracy: 0.0769
# Epoch 64/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 11310.5371 - accuracy: 0.0769
# Epoch 65/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 11414.5723 - accuracy: 0.0769
# Epoch 66/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 11521.5459 - accuracy: 0.0769
# Epoch 67/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 11631.4629 - accuracy: 0.0769
# Epoch 68/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 11744.3262 - accuracy: 0.0769
# Epoch 69/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 11860.1367 - accuracy: 0.0769
# Epoch 70/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 11978.9082 - accuracy: 0.0769
# Epoch 71/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 12100.6455 - accuracy: 0.0769
# Epoch 72/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 12225.3594 - accuracy: 0.0769
# Epoch 73/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 12353.0615 - accuracy: 0.0769
# Epoch 74/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 12483.7617 - accuracy: 0.0769
# Epoch 75/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 12617.4736 - accuracy: 0.0769
# Epoch 76/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 12754.2070 - accuracy: 0.0769
# Epoch 77/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 12893.9756 - accuracy: 0.0769
# Epoch 78/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 13036.7910 - accuracy: 0.0769
# Epoch 79/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 13182.6621 - accuracy: 0.0769
# Epoch 80/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 13331.6025 - accuracy: 0.0769
# Epoch 81/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 13483.6230 - accuracy: 0.0769
# Epoch 82/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 13638.7285 - accuracy: 0.0769
# Epoch 83/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 13796.9326 - accuracy: 0.0769
# Epoch 84/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 13958.2432 - accuracy: 0.0769
# Epoch 85/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 14122.6660 - accuracy: 0.0769
# Epoch 86/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 14290.2051 - accuracy: 0.0769
# Epoch 87/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 14460.8750 - accuracy: 0.0769
# Epoch 88/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 14634.6719 - accuracy: 0.0769
# Epoch 89/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 14811.6045 - accuracy: 0.0769
# Epoch 90/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 14991.6758 - accuracy: 0.0769
# Epoch 91/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 15174.8867 - accuracy: 0.0769
# Epoch 92/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 15361.2412 - accuracy: 0.0769
# Epoch 93/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 15550.7393 - accuracy: 0.0769
# Epoch 94/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 15743.3809 - accuracy: 0.0769
# Epoch 95/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 15939.1680 - accuracy: 0.0769
# Epoch 96/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 16138.0986 - accuracy: 0.0769
# Epoch 97/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 16340.1680 - accuracy: 0.0769
# Epoch 98/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 16545.3789 - accuracy: 0.0769
# Epoch 99/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 16753.7266 - accuracy: 0.0769
# Epoch 100/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 16965.2070 - accuracy: 0.0769
# Epoch 101/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 17179.8164 - accuracy: 0.0769
# Epoch 102/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 17397.5527 - accuracy: 0.0769
# Epoch 103/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 17618.4141 - accuracy: 0.0769
# Epoch 104/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 17842.3887 - accuracy: 0.0769
# Epoch 105/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 18069.4746 - accuracy: 0.0769
# Epoch 106/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 18299.6680 - accuracy: 0.0769
# Epoch 107/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 18532.9609 - accuracy: 0.0769
# Epoch 108/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 18769.3516 - accuracy: 0.0769
# Epoch 109/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 19008.8301 - accuracy: 0.0769
# Epoch 110/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 19251.3945 - accuracy: 0.0769
# Epoch 111/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 19497.0371 - accuracy: 0.0769
# Epoch 112/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 19745.7500 - accuracy: 0.0769
# Epoch 113/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 19997.5312 - accuracy: 0.0769
# Epoch 114/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 20252.3730 - accuracy: 0.0769
# Epoch 115/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 20510.2695 - accuracy: 0.0769
# Epoch 116/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 20771.2148 - accuracy: 0.0769
# Epoch 117/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 21035.2012 - accuracy: 0.0769
# Epoch 118/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 21302.2305 - accuracy: 0.0769
# Epoch 119/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 21572.2910 - accuracy: 0.0769
# Epoch 120/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 21845.3770 - accuracy: 0.0769
# Epoch 121/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 22121.4863 - accuracy: 0.0769
# Epoch 122/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 22400.6055 - accuracy: 0.0769
# Epoch 123/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 22682.7461 - accuracy: 0.0769
# Epoch 124/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 22967.8887 - accuracy: 0.0769
# Epoch 125/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 23256.0332 - accuracy: 0.0769
# Epoch 126/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 23547.1777 - accuracy: 0.0769
# Epoch 127/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 23841.3125 - accuracy: 0.0769
# Epoch 128/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 24138.4375 - accuracy: 0.0769
# Epoch 129/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 24438.5488 - accuracy: 0.0769
# Epoch 130/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 24741.6387 - accuracy: 0.0769
# Epoch 131/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 25047.7090 - accuracy: 0.0769
# Epoch 132/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 25356.7500 - accuracy: 0.0769
# Epoch 133/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 25668.7598 - accuracy: 0.0769
# Epoch 134/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 25983.7402 - accuracy: 0.0769
# Epoch 135/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 26301.6836 - accuracy: 0.0769
# Epoch 136/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 26622.5859 - accuracy: 0.0769
# Epoch 137/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 26946.4414 - accuracy: 0.0769
# Epoch 138/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 27273.2578 - accuracy: 0.0769
# Epoch 139/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 27603.0195 - accuracy: 0.0769
# Epoch 140/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 27935.7363 - accuracy: 0.0769
# Epoch 141/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 28271.3984 - accuracy: 0.0769
# Epoch 142/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 28610.0039 - accuracy: 0.0769
# Epoch 143/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 28951.5488 - accuracy: 0.0769
# Epoch 144/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 29296.0391 - accuracy: 0.0769
# Epoch 145/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 29643.4609 - accuracy: 0.0769
# Epoch 146/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 29993.8242 - accuracy: 0.0769
# Epoch 147/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 30347.1172 - accuracy: 0.0769
# Epoch 148/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 30703.3398 - accuracy: 0.0769
# Epoch 149/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 31062.4922 - accuracy: 0.0769
# Epoch 150/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 31424.5762 - accuracy: 0.0769
# Epoch 151/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 31789.5859 - accuracy: 0.0769
# Epoch 152/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 32157.5215 - accuracy: 0.0769
# Epoch 153/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 32528.3770 - accuracy: 0.0769
# Epoch 154/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 32902.1523 - accuracy: 0.0769
# Epoch 155/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 33278.8516 - accuracy: 0.0769
# Epoch 156/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 33658.4688 - accuracy: 0.0769
# Epoch 157/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 34040.9961 - accuracy: 0.0769
# Epoch 158/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 34426.4414 - accuracy: 0.0769
# Epoch 159/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 34814.8047 - accuracy: 0.0769
# Epoch 160/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 35206.0781 - accuracy: 0.0769
# Epoch 161/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 35600.2539 - accuracy: 0.0769
# Epoch 162/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 35997.3398 - accuracy: 0.0769
# Epoch 163/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 36397.3398 - accuracy: 0.0769
# Epoch 164/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 36800.2383 - accuracy: 0.0769
# Epoch 165/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 37206.0391 - accuracy: 0.0769
# Epoch 166/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 37614.7461 - accuracy: 0.0769
# Epoch 167/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 38026.3555 - accuracy: 0.0769
# Epoch 168/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 38440.8594 - accuracy: 0.0769
# Epoch 169/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 38858.2578 - accuracy: 0.0769
# Epoch 170/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 39278.5547 - accuracy: 0.0769
# Epoch 171/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 39701.7422 - accuracy: 0.0769
# Epoch 172/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 40127.8203 - accuracy: 0.0769
# Epoch 173/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 40556.7969 - accuracy: 0.0769
# Epoch 174/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 40988.6484 - accuracy: 0.0769
# Epoch 175/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 41423.3945 - accuracy: 0.0769
# Epoch 176/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 41861.0234 - accuracy: 0.0769
# Epoch 177/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 42301.5352 - accuracy: 0.0769
# Epoch 178/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 42744.9297 - accuracy: 0.0769
# Epoch 179/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 43191.1953 - accuracy: 0.0769
# Epoch 180/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 43640.3398 - accuracy: 0.0769
# Epoch 181/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 44092.3594 - accuracy: 0.0769
# Epoch 182/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 44547.2500 - accuracy: 0.0769
# Epoch 183/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 45005.0195 - accuracy: 0.0769
# Epoch 184/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 45465.6523 - accuracy: 0.0769
# Epoch 185/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 45929.1602 - accuracy: 0.0769
# Epoch 186/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 46395.5078 - accuracy: 0.0769
# Epoch 187/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 46864.7422 - accuracy: 0.0769
# Epoch 188/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 47336.8281 - accuracy: 0.0769
# Epoch 189/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 47811.7734 - accuracy: 0.0769
# Epoch 190/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 48289.5664 - accuracy: 0.0769
# Epoch 191/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 48770.2305 - accuracy: 0.0769
# Epoch 192/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 49253.7305 - accuracy: 0.0769
# Epoch 193/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 49740.0977 - accuracy: 0.0769
# Epoch 194/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 50229.3086 - accuracy: 0.0769
# Epoch 195/1000
# 1/1 [==============================] - ETA: 0s - loss: 50721.3594 - accuracy: 0.07 - 0s 7ms/step - loss: 50721.3594 - accuracy: 0.0769
# Epoch 196/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 51216.2539 - accuracy: 0.0769
# Epoch 197/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 51714.0039 - accuracy: 0.0769
# Epoch 198/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 52214.5820 - accuracy: 0.0769
# Epoch 199/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 52718.0039 - accuracy: 0.0769
# Epoch 200/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 53224.2656 - accuracy: 0.0769
# Epoch 201/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 53733.3672 - accuracy: 0.0769
# Epoch 202/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 54245.2969 - accuracy: 0.0769
# Epoch 203/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 54760.0664 - accuracy: 0.0769
# Epoch 204/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 55277.6680 - accuracy: 0.0769
# Epoch 205/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 55798.1055 - accuracy: 0.0769
# Epoch 206/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 56321.3555 - accuracy: 0.0769
# Epoch 207/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 56847.4414 - accuracy: 0.0769
# Epoch 208/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 57376.3672 - accuracy: 0.0769
# Epoch 209/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 57908.1094 - accuracy: 0.0769
# Epoch 210/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 58442.6719 - accuracy: 0.0769
# Epoch 211/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 58980.0625 - accuracy: 0.0769
# Epoch 212/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 59520.2773 - accuracy: 0.0769
# Epoch 213/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 60063.3164 - accuracy: 0.0769
# Epoch 214/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 60609.1797 - accuracy: 0.0769
# Epoch 215/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 61157.8594 - accuracy: 0.0769
# Epoch 216/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 61709.3672 - accuracy: 0.0769
# Epoch 217/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 62263.6836 - accuracy: 0.0769
# Epoch 218/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 62820.8125 - accuracy: 0.0769
# Epoch 219/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 63380.7734 - accuracy: 0.0769
# Epoch 220/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 63943.5547 - accuracy: 0.0769
# Epoch 221/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 64509.1406 - accuracy: 0.0769
# Epoch 222/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 65077.5547 - accuracy: 0.0769
# Epoch 223/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 65648.7812 - accuracy: 0.0769
# Epoch 224/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 66222.8047 - accuracy: 0.0769
# Epoch 225/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 66799.6719 - accuracy: 0.0769
# Epoch 226/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 67379.3359 - accuracy: 0.0769
# Epoch 227/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 67961.8203 - accuracy: 0.0769
# Epoch 228/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 68547.1250 - accuracy: 0.0769
# Epoch 229/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 69135.2344 - accuracy: 0.0769
# Epoch 230/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 69726.1562 - accuracy: 0.0769
# Epoch 231/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 70319.8828 - accuracy: 0.0769
# Epoch 232/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 70916.4297 - accuracy: 0.0769
# Epoch 233/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 71515.7891 - accuracy: 0.0769
# Epoch 234/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 72117.9453 - accuracy: 0.0769
# Epoch 235/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 72722.9219 - accuracy: 0.0769
# Epoch 236/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 73330.7031 - accuracy: 0.0769
# Epoch 237/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 73941.2969 - accuracy: 0.0769
# Epoch 238/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 74554.6953 - accuracy: 0.0769
# Epoch 239/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 75170.9062 - accuracy: 0.0769
# Epoch 240/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 75789.9219 - accuracy: 0.0769
# Epoch 241/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 76411.7188 - accuracy: 0.0769
# Epoch 242/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 77036.3594 - accuracy: 0.0769
# Epoch 243/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 77663.7656 - accuracy: 0.0769
# Epoch 244/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 78293.9922 - accuracy: 0.0769
# Epoch 245/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 78927.0391 - accuracy: 0.0769
# Epoch 246/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 79562.8594 - accuracy: 0.0769
# Epoch 247/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 80201.4766 - accuracy: 0.0769
# Epoch 248/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 80842.9141 - accuracy: 0.0769
# Epoch 249/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 81487.1406 - accuracy: 0.0769
# Epoch 250/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 82134.1641 - accuracy: 0.0769
# Epoch 251/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 82784.0078 - accuracy: 0.0769
# Epoch 252/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 83436.6172 - accuracy: 0.0769
# Epoch 253/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 84092.0391 - accuracy: 0.0769
# Epoch 254/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 84750.2344 - accuracy: 0.0769
# Epoch 255/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 85411.2500 - accuracy: 0.0769
# Epoch 256/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 86075.0469 - accuracy: 0.0769
# Epoch 257/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 86741.6328 - accuracy: 0.0769
# Epoch 258/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 87411.0078 - accuracy: 0.0769
# Epoch 259/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 88083.1719 - accuracy: 0.0769
# Epoch 260/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 88758.1328 - accuracy: 0.0769
# Epoch 261/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 89435.8828 - accuracy: 0.0769
# Epoch 262/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 90116.4141 - accuracy: 0.0769
# Epoch 263/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 90799.7344 - accuracy: 0.0769
# Epoch 264/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 91485.8281 - accuracy: 0.0769
# Epoch 265/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 92174.7109 - accuracy: 0.0769
# Epoch 266/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 92866.3750 - accuracy: 0.0769
# Epoch 267/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 93560.8203 - accuracy: 0.0769
# Epoch 268/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 94258.0547 - accuracy: 0.0769
# Epoch 269/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 94958.0547 - accuracy: 0.0769
# Epoch 270/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 95660.8438 - accuracy: 0.0769
# Epoch 271/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 96366.4141 - accuracy: 0.0769
# Epoch 272/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 97074.7500 - accuracy: 0.0769
# Epoch 273/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 97785.8594 - accuracy: 0.0769
# Epoch 274/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 98499.7500 - accuracy: 0.0769
# Epoch 275/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 99216.4219 - accuracy: 0.0769
# Epoch 276/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 99935.8359 - accuracy: 0.0769
# Epoch 277/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 100658.0391 - accuracy: 0.0769
# Epoch 278/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 101383.0156 - accuracy: 0.0769
# Epoch 279/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 102110.7578 - accuracy: 0.0769
# Epoch 280/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 102841.2500 - accuracy: 0.0769
# Epoch 281/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 103574.5391 - accuracy: 0.0769
# Epoch 282/1000
# 1/1 [==============================] - ETA: 0s - loss: 104310.5703 - accuracy: 0.076 - 0s 5ms/step - loss: 104310.5703 - accuracy: 0.0769
# Epoch 283/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 105049.3672 - accuracy: 0.0769
# Epoch 284/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 105790.9297 - accuracy: 0.0769
# Epoch 285/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 106535.2578 - accuracy: 0.0769
# Epoch 286/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 107282.3438 - accuracy: 0.0769
# Epoch 287/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 108032.1797 - accuracy: 0.0769
# Epoch 288/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 108784.7656 - accuracy: 0.0769
# Epoch 289/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 109540.1328 - accuracy: 0.0769
# Epoch 290/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 110298.2578 - accuracy: 0.0769
# Epoch 291/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 111059.1172 - accuracy: 0.0769
# Epoch 292/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 111822.7500 - accuracy: 0.0769
# Epoch 293/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 112589.1172 - accuracy: 0.0769
# Epoch 294/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 113358.2344 - accuracy: 0.0769
# Epoch 295/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 114130.1172 - accuracy: 0.0769
# Epoch 296/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 114904.7422 - accuracy: 0.0769
# Epoch 297/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 115682.1172 - accuracy: 0.0769
# Epoch 298/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 116462.2188 - accuracy: 0.0769
# Epoch 299/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 117245.0859 - accuracy: 0.0769
# Epoch 300/1000
# 1/1 [==============================] - ETA: 0s - loss: 118030.6953 - accuracy: 0.076 - 0s 5ms/step - loss: 118030.6953 - accuracy: 0.0769
# Epoch 301/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 118819.0312 - accuracy: 0.0769
# Epoch 302/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 119610.1250 - accuracy: 0.0769
# Epoch 303/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 120403.9219 - accuracy: 0.0769
# Epoch 304/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 121200.5156 - accuracy: 0.0769
# Epoch 305/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 121999.8047 - accuracy: 0.0769
# Epoch 306/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 122801.8281 - accuracy: 0.0769
# Epoch 307/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 123606.6172 - accuracy: 0.0769
# Epoch 308/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 124414.1328 - accuracy: 0.0769
# Epoch 309/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 125224.3828 - accuracy: 0.0769
# Epoch 310/1000
# 1/1 [==============================] - ETA: 0s - loss: 126037.3359 - accuracy: 0.076 - 0s 7ms/step - loss: 126037.3359 - accuracy: 0.0769
# Epoch 311/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 126853.0547 - accuracy: 0.0769
# Epoch 312/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 127671.5000 - accuracy: 0.0769
# Epoch 313/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 128492.6641 - accuracy: 0.0769
# Epoch 314/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 129316.5547 - accuracy: 0.0769
# Epoch 315/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 130143.1641 - accuracy: 0.0769
# Epoch 316/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 130972.5000 - accuracy: 0.0769
# Epoch 317/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 131804.5625 - accuracy: 0.0769
# Epoch 318/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 132639.3594 - accuracy: 0.0769
# Epoch 319/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 133476.8594 - accuracy: 0.0769
# Epoch 320/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 134317.0938 - accuracy: 0.0769
# Epoch 321/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 135160.0312 - accuracy: 0.0769
# Epoch 322/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 136005.6875 - accuracy: 0.0769
# Epoch 323/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 136854.0625 - accuracy: 0.0769
# Epoch 324/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 137705.1562 - accuracy: 0.0769
# Epoch 325/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 138558.9688 - accuracy: 0.0769
# Epoch 326/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 139415.4844 - accuracy: 0.0769
# Epoch 327/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 140274.7188 - accuracy: 0.0769
# Epoch 328/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 141136.6719 - accuracy: 0.0769
# Epoch 329/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 142001.2969 - accuracy: 0.0769
# Epoch 330/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 142868.6406 - accuracy: 0.0769
# Epoch 331/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 143738.7188 - accuracy: 0.0769
# Epoch 332/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 144611.4688 - accuracy: 0.0769
# Epoch 333/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 145486.9375 - accuracy: 0.0769
# Epoch 334/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 146365.1094 - accuracy: 0.0769
# Epoch 335/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 147245.9844 - accuracy: 0.0769
# Epoch 336/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 148129.5469 - accuracy: 0.0769
# Epoch 337/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 149015.8125 - accuracy: 0.0769
# Epoch 338/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 149904.7812 - accuracy: 0.0769
# Epoch 339/1000
# 1/1 [==============================] - 0s 208ms/step - loss: 150796.4375 - accuracy: 0.0769
# Epoch 340/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 151690.8125 - accuracy: 0.0769
# Epoch 341/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 152587.8438 - accuracy: 0.0769
# Epoch 342/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 153487.5781 - accuracy: 0.0769
# Epoch 343/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 154390.0000 - accuracy: 0.0769
# Epoch 344/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 155295.1406 - accuracy: 0.0769
# Epoch 345/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 156202.9375 - accuracy: 0.0769
# Epoch 346/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 157113.4062 - accuracy: 0.0769
# Epoch 347/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 158026.5781 - accuracy: 0.0769
# Epoch 348/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 158942.4375 - accuracy: 0.0769
# Epoch 349/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 159860.9844 - accuracy: 0.0769
# Epoch 350/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 160782.1719 - accuracy: 0.0769
# Epoch 351/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 161706.0938 - accuracy: 0.0769
# Epoch 352/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 162632.6406 - accuracy: 0.0769
# Epoch 353/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 163561.8906 - accuracy: 0.0769
# Epoch 354/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 164493.8281 - accuracy: 0.0769
# Epoch 355/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 165428.4062 - accuracy: 0.0769
# Epoch 356/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 166365.6719 - accuracy: 0.0769
# Epoch 357/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 167305.6094 - accuracy: 0.0769
# Epoch 358/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 168248.2344 - accuracy: 0.0769
# Epoch 359/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 169193.5000 - accuracy: 0.0769
# Epoch 360/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 170141.4688 - accuracy: 0.0769
# Epoch 361/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 171092.0625 - accuracy: 0.0769
# Epoch 362/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 172045.3125 - accuracy: 0.0769
# Epoch 363/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 173001.2812 - accuracy: 0.0769
# Epoch 364/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 173959.8281 - accuracy: 0.0769
# Epoch 365/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 174921.0781 - accuracy: 0.0769
# Epoch 366/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 175884.9844 - accuracy: 0.0769
# Epoch 367/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 176851.5625 - accuracy: 0.0769
# Epoch 368/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 177820.7656 - accuracy: 0.0769
# Epoch 369/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 178792.6562 - accuracy: 0.0769
# Epoch 370/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 179767.1562 - accuracy: 0.0769
# Epoch 371/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 180744.3438 - accuracy: 0.0769
# Epoch 372/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 181724.1562 - accuracy: 0.0769
# Epoch 373/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 182706.6406 - accuracy: 0.0769
# Epoch 374/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 183691.6875 - accuracy: 0.0769
# Epoch 375/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 184679.4844 - accuracy: 0.0769
# Epoch 376/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 185669.8438 - accuracy: 0.0769
# Epoch 377/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 186662.9062 - accuracy: 0.0769
# Epoch 378/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 187658.5625 - accuracy: 0.0769
# Epoch 379/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 188656.9062 - accuracy: 0.0769
# Epoch 380/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 189657.8281 - accuracy: 0.0769
# Epoch 381/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 190661.4219 - accuracy: 0.0769
# Epoch 382/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 191667.6406 - accuracy: 0.0769
# Epoch 383/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 192676.4844 - accuracy: 0.0769
# Epoch 384/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 193687.9688 - accuracy: 0.0769
# Epoch 385/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 194702.0625 - accuracy: 0.0769
# Epoch 386/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 195718.7656 - accuracy: 0.0769
# Epoch 387/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 196738.1406 - accuracy: 0.0769
# Epoch 388/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 197760.1562 - accuracy: 0.0769
# Epoch 389/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 198784.7500 - accuracy: 0.0769
# Epoch 390/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 199811.9844 - accuracy: 0.0769
# Epoch 391/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 200841.8125 - accuracy: 0.0769
# Epoch 392/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 201874.2656 - accuracy: 0.0769
# Epoch 393/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 202909.3594 - accuracy: 0.0769
# Epoch 394/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 203947.0625 - accuracy: 0.0769
# Epoch 395/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 204987.3438 - accuracy: 0.0769
# Epoch 396/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 206030.2812 - accuracy: 0.0769
# Epoch 397/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 207075.7656 - accuracy: 0.0769
# Epoch 398/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 208123.9688 - accuracy: 0.0769
# Epoch 399/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 209174.7344 - accuracy: 0.0769
# Epoch 400/1000
# 1/1 [==============================] - 0s 195ms/step - loss: 210228.0625 - accuracy: 0.0769
# Epoch 401/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 211284.0312 - accuracy: 0.0769
# Epoch 402/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 212342.6094 - accuracy: 0.0769
# Epoch 403/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 213403.7656 - accuracy: 0.0769
# Epoch 404/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 214467.5312 - accuracy: 0.0769
# Epoch 405/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 215533.9219 - accuracy: 0.0769
# Epoch 406/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 216602.8594 - accuracy: 0.0769
# Epoch 407/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 217674.4219 - accuracy: 0.0769
# Epoch 408/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 218748.5781 - accuracy: 0.0769
# Epoch 409/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 219825.3438 - accuracy: 0.0769
# Epoch 410/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 220904.6719 - accuracy: 0.0769
# Epoch 411/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 221986.5781 - accuracy: 0.0769
# Epoch 412/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 223071.1406 - accuracy: 0.0769
# Epoch 413/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 224158.2656 - accuracy: 0.0769
# Epoch 414/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 225247.9688 - accuracy: 0.0769
# Epoch 415/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 226340.2656 - accuracy: 0.0769
# Epoch 416/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 227435.1406 - accuracy: 0.0769
# Epoch 417/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 228532.5625 - accuracy: 0.0769
# Epoch 418/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 229632.5938 - accuracy: 0.0769
# Epoch 419/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 230735.2188 - accuracy: 0.0769
# Epoch 420/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 231840.3438 - accuracy: 0.0769
# Epoch 421/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 232948.1562 - accuracy: 0.0769
# Epoch 422/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 234058.5000 - accuracy: 0.0769
# Epoch 423/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 235171.4375 - accuracy: 0.0769
# Epoch 424/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 236286.9844 - accuracy: 0.0769
# Epoch 425/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 237405.0000 - accuracy: 0.0769
# Epoch 426/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 238525.6562 - accuracy: 0.0769
# Epoch 427/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 239648.8438 - accuracy: 0.0769
# Epoch 428/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 240774.6406 - accuracy: 0.0769
# Epoch 429/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 241903.0000 - accuracy: 0.0769
# Epoch 430/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 243033.9062 - accuracy: 0.0769
# Epoch 431/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 244167.3906 - accuracy: 0.0769
# Epoch 432/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 245303.4375 - accuracy: 0.0769
# Epoch 433/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 246442.0312 - accuracy: 0.0769
# Epoch 434/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 247583.1562 - accuracy: 0.0769
# Epoch 435/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 248726.9375 - accuracy: 0.0769
# Epoch 436/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 249873.2344 - accuracy: 0.0769
# Epoch 437/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 251022.0781 - accuracy: 0.0769
# Epoch 438/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 252173.4688 - accuracy: 0.0769
# Epoch 439/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 253327.3594 - accuracy: 0.0769
# Epoch 440/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 254483.9688 - accuracy: 0.0769
# Epoch 441/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 255643.0000 - accuracy: 0.0769
# Epoch 442/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 256804.5938 - accuracy: 0.0769
# Epoch 443/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 257968.7656 - accuracy: 0.0769
# Epoch 444/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 259135.4844 - accuracy: 0.0769
# Epoch 445/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 260304.7344 - accuracy: 0.0769
# Epoch 446/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 261476.5781 - accuracy: 0.0769
# Epoch 447/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 262650.9062 - accuracy: 0.0769
# Epoch 448/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 263827.8438 - accuracy: 0.0769
# Epoch 449/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 265007.2812 - accuracy: 0.0769
# Epoch 450/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 266189.2812 - accuracy: 0.0769
# Epoch 451/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 267373.8125 - accuracy: 0.0769
# Epoch 452/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 268560.8438 - accuracy: 0.0769
# Epoch 453/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 269750.5000 - accuracy: 0.0769
# Epoch 454/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 270942.6562 - accuracy: 0.0769
# Epoch 455/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 272137.3125 - accuracy: 0.0769
# Epoch 456/1000
# ...
# Epoch 851/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 936226.4375 - accuracy: 0.0769
# Epoch 852/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 938361.6875 - accuracy: 0.0769
# Epoch 853/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 940498.9375 - accuracy: 0.0769
# Epoch 854/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 942638.3125 - accuracy: 0.0769
# Epoch 855/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 944779.8750 - accuracy: 0.0769
# Epoch 856/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 946923.7500 - accuracy: 0.0769
# Epoch 857/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 949069.5625 - accuracy: 0.0769
# Epoch 858/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 951217.8750 - accuracy: 0.0769
# Epoch 859/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 953368.0000 - accuracy: 0.0769
# Epoch 860/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 955520.6250 - accuracy: 0.0769
# Epoch 861/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 957675.0000 - accuracy: 0.0769
# Epoch 862/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 959831.7500 - accuracy: 0.0769
# Epoch 863/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 961991.0625 - accuracy: 0.0769
# Epoch 864/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 964152.6250 - accuracy: 0.0769
# Epoch 865/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 966316.0000 - accuracy: 0.0769
# Epoch 866/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 968481.4375 - accuracy: 0.0769
# Epoch 867/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 970649.3750 - accuracy: 0.0769
# Epoch 868/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 972819.1250 - accuracy: 0.0769
# Epoch 869/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 974991.2500 - accuracy: 0.0769
# Epoch 870/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 977165.5625 - accuracy: 0.0769
# Epoch 871/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 979342.0000 - accuracy: 0.0769
# Epoch 872/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 981520.6875 - accuracy: 0.0769
# Epoch 873/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 983701.5625 - accuracy: 0.0769
# Epoch 874/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 985884.6250 - accuracy: 0.0769
# Epoch 875/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 988070.0625 - accuracy: 0.0769
# Epoch 876/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 990257.2500 - accuracy: 0.0769
# Epoch 877/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 992447.0000 - accuracy: 0.0769
# Epoch 878/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 994638.4375 - accuracy: 0.0769
# Epoch 879/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 996832.0625 - accuracy: 0.0769
# Epoch 880/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 999028.3125 - accuracy: 0.0769
# Epoch 881/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1001226.6250 - accuracy: 0.0769
# Epoch 882/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1003427.0000 - accuracy: 0.0769
# Epoch 883/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1005629.5625 - accuracy: 0.0769
# Epoch 884/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1007834.1250 - accuracy: 0.0769
# Epoch 885/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1010041.1250 - accuracy: 0.0769
# Epoch 886/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1012250.2500 - accuracy: 0.0769
# Epoch 887/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1014461.5625 - accuracy: 0.0769
# Epoch 888/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1016674.6875 - accuracy: 0.0769
# Epoch 889/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1018890.2500 - accuracy: 0.0769
# Epoch 890/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1021107.7500 - accuracy: 0.0769
# Epoch 891/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1023327.6250 - accuracy: 0.0769
# Epoch 892/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1025549.6875 - accuracy: 0.0769
# Epoch 893/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1027773.8750 - accuracy: 0.0769
# Epoch 894/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1030000.4375 - accuracy: 0.0769
# Epoch 895/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1032229.0625 - accuracy: 0.0769
# Epoch 896/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1034459.7500 - accuracy: 0.0769
# Epoch 897/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1036692.4375 - accuracy: 0.0769
# Epoch 898/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1038927.5625 - accuracy: 0.0769
# Epoch 899/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1041164.7500 - accuracy: 0.0769
# Epoch 900/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1043403.8750 - accuracy: 0.0769
# Epoch 901/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1045645.2500 - accuracy: 0.0769
# Epoch 902/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1047888.8750 - accuracy: 0.0769
# Epoch 903/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1050134.6250 - accuracy: 0.0769
# Epoch 904/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1052382.6250 - accuracy: 0.0769
# Epoch 905/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1054632.7500 - accuracy: 0.0769
# Epoch 906/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1056885.1250 - accuracy: 0.0769
# Epoch 907/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1059139.3750 - accuracy: 0.0769
# Epoch 908/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1061396.1250 - accuracy: 0.0769
# Epoch 909/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1063654.7500 - accuracy: 0.0769
# Epoch 910/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1065915.5000 - accuracy: 0.0769
# Epoch 911/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1068178.5000 - accuracy: 0.0769
# Epoch 912/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1070443.5000 - accuracy: 0.0769
# Epoch 913/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1072710.8750 - accuracy: 0.0769
# Epoch 914/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1074980.2500 - accuracy: 0.0769
# Epoch 915/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1077251.8750 - accuracy: 0.0769
# Epoch 916/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 1079525.6250 - accuracy: 0.0769
# Epoch 917/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1081801.5000 - accuracy: 0.0769
# Epoch 918/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1084079.6250 - accuracy: 0.0769
# Epoch 919/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1086359.7500 - accuracy: 0.0769
# Epoch 920/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1088642.1250 - accuracy: 0.0769
# Epoch 921/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 1090926.5000 - accuracy: 0.0769
# Epoch 922/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1093213.1250 - accuracy: 0.0769
# Epoch 923/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1095501.8750 - accuracy: 0.0769
# Epoch 924/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1097792.5000 - accuracy: 0.0769
# Epoch 925/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1100085.8750 - accuracy: 0.0769
# Epoch 926/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1102380.8750 - accuracy: 0.0769
# Epoch 927/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1104678.1250 - accuracy: 0.0769
# Epoch 928/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 1106977.5000 - accuracy: 0.0769
# Epoch 929/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1109279.2500 - accuracy: 0.0769
# Epoch 930/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1111582.8750 - accuracy: 0.0769
# Epoch 931/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1113888.6250 - accuracy: 0.0769
# Epoch 932/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1116196.5000 - accuracy: 0.0769
# Epoch 933/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1118506.6250 - accuracy: 0.0769
# Epoch 934/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1120819.0000 - accuracy: 0.0769
# Epoch 935/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 1123133.5000 - accuracy: 0.0769
# Epoch 936/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1125449.7500 - accuracy: 0.0769
# Epoch 937/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1127768.6250 - accuracy: 0.0769
# Epoch 938/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1130089.5000 - accuracy: 0.0769
# Epoch 939/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1132412.2500 - accuracy: 0.0769
# Epoch 940/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1134737.8750 - accuracy: 0.0769
# Epoch 941/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1137064.5000 - accuracy: 0.0769
# Epoch 942/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1139393.7500 - accuracy: 0.0769
# Epoch 943/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1141725.2500 - accuracy: 0.0769
# Epoch 944/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1144058.8750 - accuracy: 0.0769
# Epoch 945/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1146394.6250 - accuracy: 0.0769
# Epoch 946/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1148732.2500 - accuracy: 0.0769
# Epoch 947/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 1151072.5000 - accuracy: 0.0769
# Epoch 948/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1153414.5000 - accuracy: 0.0769
# Epoch 949/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1155758.7500 - accuracy: 0.0769
# Epoch 950/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1158105.1250 - accuracy: 0.0769
# Epoch 951/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1160453.5000 - accuracy: 0.0769
# Epoch 952/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1162803.7500 - accuracy: 0.0769
# Epoch 953/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1165156.6250 - accuracy: 0.0769
# Epoch 954/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1167511.5000 - accuracy: 0.0769
# Epoch 955/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1169868.2500 - accuracy: 0.0769
# Epoch 956/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1172227.2500 - accuracy: 0.0769
# Epoch 957/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1174588.6250 - accuracy: 0.0769
# Epoch 958/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1176952.1250 - accuracy: 0.0769
# Epoch 959/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1179317.7500 - accuracy: 0.0769
# Epoch 960/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1181685.1250 - accuracy: 0.0769
# Epoch 961/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 1184054.7500 - accuracy: 0.0769
# Epoch 962/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1186426.1250 - accuracy: 0.0769
# Epoch 963/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1188800.2500 - accuracy: 0.0769
# Epoch 964/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1191176.3750 - accuracy: 0.0769
# Epoch 965/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1193554.2500 - accuracy: 0.0769
# Epoch 966/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1195934.5000 - accuracy: 0.0769
# Epoch 967/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1198316.7500 - accuracy: 0.0769
# Epoch 968/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1200701.2500 - accuracy: 0.0769
# Epoch 969/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1203088.0000 - accuracy: 0.0769
# Epoch 970/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1205476.7500 - accuracy: 0.0769
# Epoch 971/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1207867.5000 - accuracy: 0.0769
# Epoch 972/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 1210260.5000 - accuracy: 0.0769
# Epoch 973/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1212655.2500 - accuracy: 0.0769
# Epoch 974/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1215052.1250 - accuracy: 0.0769
# Epoch 975/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1217451.5000 - accuracy: 0.0769
# Epoch 976/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1219852.7500 - accuracy: 0.0769
# Epoch 977/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1222256.3750 - accuracy: 0.0769
# Epoch 978/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1224662.0000 - accuracy: 0.0769
# Epoch 979/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1227069.6250 - accuracy: 0.0769
# Epoch 980/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1229479.7500 - accuracy: 0.0769
# Epoch 981/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1231891.2500 - accuracy: 0.0769
# Epoch 982/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1234305.1250 - accuracy: 0.0769
# Epoch 983/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1236720.8750 - accuracy: 0.0769
# Epoch 984/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1239139.2500 - accuracy: 0.0769
# Epoch 985/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1241559.3750 - accuracy: 0.0769
# Epoch 986/1000
# 1/1 [==============================] - ETA: 0s - loss: 1243981.7500 - accuracy: 0.07 - 0s 7ms/step - loss: 1243981.7500 - accuracy: 0.0769
# Epoch 987/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1246406.1250 - accuracy: 0.0769
# Epoch 988/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1248832.7500 - accuracy: 0.0769
# Epoch 989/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1251261.5000 - accuracy: 0.0769
# Epoch 990/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1253692.5000 - accuracy: 0.0769
# Epoch 991/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 1256125.1250 - accuracy: 0.0769
# Epoch 992/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1258560.2500 - accuracy: 0.0769
# Epoch 993/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1260997.2500 - accuracy: 0.0769
# Epoch 994/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1263436.1250 - accuracy: 0.0769
# Epoch 995/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 1265877.7500 - accuracy: 0.0769
# Epoch 996/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1268320.8750 - accuracy: 0.0769
# Epoch 997/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1270766.5000 - accuracy: 0.0769
# Epoch 998/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1273214.0000 - accuracy: 0.0769
# Epoch 999/1000
# 1/1 [==============================] - 0s 5ms/step - loss: 1275663.3750 - accuracy: 0.0769
# Epoch 1000/1000
# 1/1 [==============================] - 0s 6ms/step - loss: 1278115.1250 - accuracy: 0.0769

# %%
# Get the searched line and word indeces

def get_indices(word):
    line_index = 0
    word_index = 0
    for line in file_details['line_words']:
        for wrd in line:
            if wrd==word:
                return (line_index, word_index)
            word_index = word_index + 1
        line_index = line_index + 1
    return (-1,-1)

def eq(embd1, embd2):
    isEq = True
    index = 0
    for em in embd1:
        if str(em)!=str(embd2[index]):
            isEq = False
            break
        index = index + 1
    return isEq
        
def get_ohe_indices(embedding):
    ONE = -1
    ind = 0
    for embd in word_embeddings:
        if eq(list(embedding), list(embd)):
            ONE = ind
            break
        ind = ind + 1
    
    line_index = 0
    word_index = 0
    for line in file_details['encoded_line_words']:
        for wrd in line:
            if wrd==ONE:
                return (line_index, word_index)
            word_index = word_index + 1
        line_index = line_index + 1
    return (-1,-1)

def get_word(indices):
    word = '__NoWordFound__'
    if indices!=(-1,-1):
        word = file_details['line_words'][indices[0]][indices[1]]
    return word

# %%
get_ohe_indices([ 1.6754463, -1.5663351,  1.6041586,  1.5992835, -1.6179308,
       -1.5989335,  1.6009173, -1.6389836])
# Out:
# match
# (0, 0)

# %%
get_word(get_ohe_indices([ 1.6754463, -1.5663351,  1.6041586,  1.5992835, -1.6179308,
       -1.5989335,  1.6009173, -1.6389836]))
# Out:
# match
# 'In'

# %%
# Fetch the word embeddings

def fetch_embedding(indices, word_embeddings):
    # Get the One Hote Encoding of the word using the indices 
    # and passing it to the word embeddings to find the embedding of the word
    print(indices)
    OHE = file_details['encoded_line_words'][indices[0]][indices[1]]
    return word_embeddings[OHE]

# %%
# The variable word_embeddings contains all the embeddings

word_embeddings = embedding_layer.get_weights()[0]

# %% [markdown]
# #### Now the embedding of a word can be fetched in the following way

# %%
word = 'In'
indices = get_indices(word=word)
fetch_embedding(indices=indices, word_embeddings=word_embeddings)
# Out:
# array([ 1.6754463, -1.5663351,  1.6041586,  1.5992835, -1.6179308,
#        -1.5989335,  1.6009173, -1.6389836], dtype=float32)

# %%
# Function to find the least distant word with the help of word_embeddings. 
# Here the above sample of code will be leveraged to find the embedding of 
# the two words and calculate the cosine theta distance. Let us make all possible pairs and store the distances.
# Later the least distance index can be found to map with the closest pair.
# given a word and the learned word_embeddings, this function will return the next (closest) word.
# evaluation_method is cosine for the sake of simplicity

def closest_word(word, word_embeddings):
    word_pairs = []
    word_pairs_distances = []
    line_index, word_index = get_indices(word)
    print(word_embeddings.shape)
    if (line_index == -1) or (word_index == -1):
        print("searched word not found in the given context!")
    else:
        indices = get_indices(word=word)
        embedding = fetch_embedding(indices=indices, word_embeddings=word_embeddings)
        for embd in word_embeddings:
            result = 1 - spatial.distance.cosine(embedding, embd)
            embd_wd = get_word(get_ohe_indices(embd))
            word_pairs.append(word+':'+embd_wd)
            word_pairs_distances.append(result)
            print(result, line_index, word_index)
    return {'pairs':word_pairs, 'distance':word_pairs_distances}

# %%
closest_word("2000", word_embeddings)
# Out:
# (177, 8)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/3r/hfw5ds7x10s2p6ps2ct8m4j40000gn/T/ipykernel_55404/1956099656.py in <module>
# ----> 1 closest_word("2000", word_embeddings)
#
# /var/folders/3r/hfw5ds7x10s2p6ps2ct8m4j40000gn/T/ipykernel_55404/2928256966.py in closest_word(word, word_embeddings)
#      15     else:
#      16         indices = get_indices(word=word)
# ---> 17         embedding = fetch_embedding(indices=indices, word_embeddings=word_embeddings)
#      18         for embd in word_embeddings:
#      19             result = 1 - spatial.distance.cosine(embedding, embd)
#
# /var/folders/3r/hfw5ds7x10s2p6ps2ct8m4j40000gn/T/ipykernel_55404/4167561458.py in fetch_embedding(indices, word_embeddings)
#       2
#       3 def fetch_embedding(indices, word_embeddings):
# ----> 4     OHE = file_details['encoded_line_words'][indices[0]][indices[1]]
#       5     return word_embeddings[OHE]
#
# IndexError: list index out of range

# %%
word_embeddings
# Out:
# array([[ 1.6335751 ,  1.6178044 , -1.612345  , ...,  1.616994  ,
#          1.6104059 , -1.6240797 ],
#        [ 1.6123996 , -1.5647614 , -1.6227963 , ...,  1.5612272 ,
#          1.5907208 , -1.6103846 ],
#        [ 1.6228565 , -1.6949928 , -1.5836787 , ..., -1.5964924 ,
#          1.5999836 , -1.6377378 ],
#        ...,
#        [-0.02944261, -0.03694959,  0.01670599, ...,  0.04846149,
#         -0.03712022,  0.00678299],
#        [ 1.5916709 ,  1.6333138 , -1.6397147 , ...,  1.5809885 ,
#          1.6386917 ,  1.6123034 ],
#        [-1.6357318 , -1.5744001 , -1.6236811 , ...,  1.6111745 ,
#          1.6239653 ,  1.628985  ]], dtype=float32)

# %%
file_details['line_words'][0][177]
# Out:
# ''

# %%
file_details['padded_context'][0][0]
# Out:
# 24

# %%
file_details
# Out:
# {'lines': ['In linguistics word embeddings were discussed in the research area of distributional semantics. It aims to quantify and categorize semantic similarities between linguistic items based on their distributional properties in large samples of language data. The underlying idea that "a word is characterized by the company it keeps" was popularized by Firth.',
#   'The technique of representing words as vectors has roots in the 1960s with the development of the vector space model for information retrieval. Reducing the number of dimensions using singular value decomposition then led to the introduction of latent semantic analysis in the late 1980s.In 2000 Bengio et al. provided in a series of papers the "Neural probabilistic language models" to reduce the high dimensionality of words representations in contexts by "learning a distributed representation for words". (Bengio et al, 2003). Word embeddings come in two different styles, one in which words are expressed as vectors of co-occurring words, and another in which words are expressed as vectors of linguistic contexts in which the words occur; these different styles are studied in (Lavelli et al, 2004). Roweis and Saul published in Science how to use "locally linear embedding" (LLE) to discover representations of high dimensional data structures. The area developed gradually and really took off after 2010, partly because important advances had been made since then on the quality of vectors and the training speed of the model.',
#   'There are many branches and many research groups working on word embeddings. In 2013, a team at Google led by Tomas Mikolov created word2vec, a word embedding toolkit which can train vector space models faster than the previous approaches. Most new word embedding techniques rely on a neural network architecture instead of more traditional n-gram models and unsupervised learning.',
#   'Limitations',
#   'One of the main limitations of word embeddings (word vector space models in general) is that possible meanings of a word are conflated into a single representation (a single vector in the semantic space). Sense embeddings are a solution to this problem: individual meanings of words are represented as distinct vectors in the space.',
#   'For biological sequences: BioVectors',
#   'Word embeddings for n-grams in biological sequences (e.g. DNA, RNA, and Proteins) for bioinformatics applications have been proposed by Asgari and Mofrad. Named bio-vectors (BioVec) to refer to biological sequences in general with protein-vectors (ProtVec) for proteins (amino-acid sequences) and gene-vectors (GeneVec) for gene sequences, this representation can be widely used in applications of deep learning in proteomics and genomics. The results presented by Asgari and Mofrad suggest that BioVectors can characterize biological sequences in terms of biochemical and biophysical interpretations of the underlying patterns.',
#   'Thought vectors',
#   'Thought vectors are an extension of word embeddings to entire sentences or even documents. Some researchers hope that these can improve the quality of machine translation.',
#   'Software',
#   "Software for training and using word embeddings includes Tomas Mikolov's Word2vec, Stanford University's GloVe, AllenNLP's Elmo,fastText, Gensim, Indra and Deeplearning4j. Principal Component Analysis (PCA) and T-Distributed Stochastic Neighbour Embedding (t-SNE) are both used to reduce the dimensionality of word vector spaces and visualize word embeddings and clusters.",
#   'Examples of application',
#   'For instance, the fastText is also used to calculate word embeddings for text corpora in Sketch Engine that are available online.'],
#  'line_words': [['In',
#    'linguistics',
#    'word',
#    'embeddings',
#    'were',
#    'discussed',
#    'in',
#    'the',
#    'research',
#    'area',
#    'of',
#    'distributional',
#    'semantics.',
#    'It',
#    'aims',
#    'to',
#    'quantify',
#    'and',
#    'categorize',
#    'semantic',
#    'similarities',
#    'between',
#    'linguistic',
#    'items',
#    'based',
#    'on',
#    'their',
#    'distributional',
#    'properties',
#    'in',
#    'large',
#    'samples',
#    'of',
#    'language',
#    'data.',
#    'The',
#    'underlying',
#    'idea',
#    'that',
#    '"a',
#    'word',
#    'is',
#    'characterized',
#    'by',
#    'the',
#    'company',
#    'it',
#    'keeps"',
#    'was',
#    'popularized',
#    'by',
#    'Firth.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['The',
#    'technique',
#    'of',
#    'representing',
#    'words',
#    'as',
#    'vectors',
#    'has',
#    'roots',
#    'in',
#    'the',
#    '1960s',
#    'with',
#    'the',
#    'development',
#    'of',
#    'the',
#    'vector',
#    'space',
#    'model',
#    'for',
#    'information',
#    'retrieval.',
#    'Reducing',
#    'the',
#    'number',
#    'of',
#    'dimensions',
#    'using',
#    'singular',
#    'value',
#    'decomposition',
#    'then',
#    'led',
#    'to',
#    'the',
#    'introduction',
#    'of',
#    'latent',
#    'semantic',
#    'analysis',
#    'in',
#    'the',
#    'late',
#    '1980s.In',
#    '2000',
#    'Bengio',
#    'et',
#    'al.',
#    'provided',
#    'in',
#    'a',
#    'series',
#    'of',
#    'papers',
#    'the',
#    '"Neural',
#    'probabilistic',
#    'language',
#    'models"',
#    'to',
#    'reduce',
#    'the',
#    'high',
#    'dimensionality',
#    'of',
#    'words',
#    'representations',
#    'in',
#    'contexts',
#    'by',
#    '"learning',
#    'a',
#    'distributed',
#    'representation',
#    'for',
#    'words".',
#    '(Bengio',
#    'et',
#    'al,',
#    '2003).',
#    'Word',
#    'embeddings',
#    'come',
#    'in',
#    'two',
#    'different',
#    'styles,',
#    'one',
#    'in',
#    'which',
#    'words',
#    'are',
#    'expressed',
#    'as',
#    'vectors',
#    'of',
#    'co-occurring',
#    'words,',
#    'and',
#    'another',
#    'in',
#    'which',
#    'words',
#    'are',
#    'expressed',
#    'as',
#    'vectors',
#    'of',
#    'linguistic',
#    'contexts',
#    'in',
#    'which',
#    'the',
#    'words',
#    'occur;',
#    'these',
#    'different',
#    'styles',
#    'are',
#    'studied',
#    'in',
#    '(Lavelli',
#    'et',
#    'al,',
#    '2004).',
#    'Roweis',
#    'and',
#    'Saul',
#    'published',
#    'in',
#    'Science',
#    'how',
#    'to',
#    'use',
#    '"locally',
#    'linear',
#    'embedding"',
#    '(LLE)',
#    'to',
#    'discover',
#    'representations',
#    'of',
#    'high',
#    'dimensional',
#    'data',
#    'structures.',
#    'The',
#    'area',
#    'developed',
#    'gradually',
#    'and',
#    'really',
#    'took',
#    'off',
#    'after',
#    '2010,',
#    'partly',
#    'because',
#    'important',
#    'advances',
#    'had',
#    'been',
#    'made',
#    'since',
#    'then',
#    'on',
#    'the',
#    'quality',
#    'of',
#    'vectors',
#    'and',
#    'the',
#    'training',
#    'speed',
#    'of',
#    'the',
#    'model.'],
#   ['There',
#    'are',
#    'many',
#    'branches',
#    'and',
#    'many',
#    'research',
#    'groups',
#    'working',
#    'on',
#    'word',
#    'embeddings.',
#    'In',
#    '2013,',
#    'a',
#    'team',
#    'at',
#    'Google',
#    'led',
#    'by',
#    'Tomas',
#    'Mikolov',
#    'created',
#    'word2vec,',
#    'a',
#    'word',
#    'embedding',
#    'toolkit',
#    'which',
#    'can',
#    'train',
#    'vector',
#    'space',
#    'models',
#    'faster',
#    'than',
#    'the',
#    'previous',
#    'approaches.',
#    'Most',
#    'new',
#    'word',
#    'embedding',
#    'techniques',
#    'rely',
#    'on',
#    'a',
#    'neural',
#    'network',
#    'architecture',
#    'instead',
#    'of',
#    'more',
#    'traditional',
#    'n-gram',
#    'models',
#    'and',
#    'unsupervised',
#    'learning.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['One',
#    'of',
#    'the',
#    'main',
#    'limitations',
#    'of',
#    'word',
#    'embeddings',
#    '(word',
#    'vector',
#    'space',
#    'models',
#    'in',
#    'general)',
#    'is',
#    'that',
#    'possible',
#    'meanings',
#    'of',
#    'a',
#    'word',
#    'are',
#    'conflated',
#    'into',
#    'a',
#    'single',
#    'representation',
#    '(a',
#    'single',
#    'vector',
#    'in',
#    'the',
#    'semantic',
#    'space).',
#    'Sense',
#    'embeddings',
#    'are',
#    'a',
#    'solution',
#    'to',
#    'this',
#    'problem:',
#    'individual',
#    'meanings',
#    'of',
#    'words',
#    'are',
#    'represented',
#    'as',
#    'distinct',
#    'vectors',
#    'in',
#    'the',
#    'space.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['For',
#    'biological',
#    'sequences:',
#    'BioVectors',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Word',
#    'embeddings',
#    'for',
#    'n-grams',
#    'in',
#    'biological',
#    'sequences',
#    '(e.g.',
#    'DNA,',
#    'RNA,',
#    'and',
#    'Proteins)',
#    'for',
#    'bioinformatics',
#    'applications',
#    'have',
#    'been',
#    'proposed',
#    'by',
#    'Asgari',
#    'and',
#    'Mofrad.',
#    'Named',
#    'bio-vectors',
#    '(BioVec)',
#    'to',
#    'refer',
#    'to',
#    'biological',
#    'sequences',
#    'in',
#    'general',
#    'with',
#    'protein-vectors',
#    '(ProtVec)',
#    'for',
#    'proteins',
#    '(amino-acid',
#    'sequences)',
#    'and',
#    'gene-vectors',
#    '(GeneVec)',
#    'for',
#    'gene',
#    'sequences,',
#    'this',
#    'representation',
#    'can',
#    'be',
#    'widely',
#    'used',
#    'in',
#    'applications',
#    'of',
#    'deep',
#    'learning',
#    'in',
#    'proteomics',
#    'and',
#    'genomics.',
#    'The',
#    'results',
#    'presented',
#    'by',
#    'Asgari',
#    'and',
#    'Mofrad',
#    'suggest',
#    'that',
#    'BioVectors',
#    'can',
#    'characterize',
#    'biological',
#    'sequences',
#    'in',
#    'terms',
#    'of',
#    'biochemical',
#    'and',
#    'biophysical',
#    'interpretations',
#    'of',
#    'the',
#    'underlying',
#    'patterns.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Thought',
#    'vectors',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Thought',
#    'vectors',
#    'are',
#    'an',
#    'extension',
#    'of',
#    'word',
#    'embeddings',
#    'to',
#    'entire',
#    'sentences',
#    'or',
#    'even',
#    'documents.',
#    'Some',
#    'researchers',
#    'hope',
#    'that',
#    'these',
#    'can',
#    'improve',
#    'the',
#    'quality',
#    'of',
#    'machine',
#    'translation.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Software',
#    'for',
#    'training',
#    'and',
#    'using',
#    'word',
#    'embeddings',
#    'includes',
#    'Tomas',
#    "Mikolov's",
#    'Word2vec,',
#    'Stanford',
#    "University's",
#    'GloVe,',
#    "AllenNLP's",
#    'Elmo,fastText,',
#    'Gensim,',
#    'Indra',
#    'and',
#    'Deeplearning4j.',
#    'Principal',
#    'Component',
#    'Analysis',
#    '(PCA)',
#    'and',
#    'T-Distributed',
#    'Stochastic',
#    'Neighbour',
#    'Embedding',
#    '(t-SNE)',
#    'are',
#    'both',
#    'used',
#    'to',
#    'reduce',
#    'the',
#    'dimensionality',
#    'of',
#    'word',
#    'vector',
#    'spaces',
#    'and',
#    'visualize',
#    'word',
#    'embeddings',
#    'and',
#    'clusters.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['Examples',
#    'of',
#    'application',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    ''],
#   ['For',
#    'instance,',
#    'the',
#    'fastText',
#    'is',
#    'also',
#    'used',
#    'to',
#    'calculate',
#    'word',
#    'embeddings',
#    'for',
#    'text',
#    'corpora',
#    'in',
#    'Sketch',
#    'Engine',
#    'that',
#    'are',
#    'available',
#    'online.',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '']],
#  'encoded_line_words': [[24,
#    31,
#    43,
#    38,
#    47,
#    12,
#    24,
#    5,
#    14,
#    50,
#    21,
#    34,
#    8,
#    14,
#    9,
#    16,
#    9,
#    39,
#    27,
#    28,
#    8,
#    6,
#    39,
#    3,
#    32,
#    51,
#    47,
#    34,
#    49,
#    24,
#    29,
#    18,
#    21,
#    43,
#    22,
#    5,
#    13,
#    39,
#    40,
#    9,
#    43,
#    1,
#    45,
#    51,
#    5,
#    12,
#    14,
#    37,
#    4,
#    29,
#    51,
#    25],
#   [14,
#    154,
#    117,
#    137,
#    3,
#    52,
#    152,
#    82,
#    95,
#    120,
#    14,
#    39,
#    37,
#    14,
#    108,
#    117,
#    14,
#    25,
#    27,
#    103,
#    102,
#    15,
#    78,
#    103,
#    14,
#    119,
#    117,
#    52,
#    169,
#    128,
#    173,
#    151,
#    138,
#    175,
#    70,
#    14,
#    15,
#    117,
#    101,
#    136,
#    88,
#    120,
#    14,
#    79,
#    5,
#    44,
#    101,
#    48,
#    61,
#    90,
#    120,
#    129,
#    87,
#    117,
#    166,
#    14,
#    153,
#    151,
#    154,
#    39,
#    70,
#    30,
#    14,
#    85,
#    141,
#    117,
#    3,
#    77,
#    120,
#    83,
#    108,
#    147,
#    129,
#    86,
#    133,
#    102,
#    3,
#    101,
#    48,
#    61,
#    156,
#    58,
#    83,
#    34,
#    120,
#    3,
#    173,
#    108,
#    175,
#    120,
#    109,
#    3,
#    176,
#    93,
#    52,
#    152,
#    117,
#    176,
#    3,
#    27,
#    102,
#    120,
#    109,
#    3,
#    176,
#    93,
#    52,
#    152,
#    117,
#    111,
#    83,
#    120,
#    109,
#    14,
#    3,
#    152,
#    103,
#    173,
#    108,
#    176,
#    148,
#    120,
#    67,
#    48,
#    61,
#    118,
#    107,
#    27,
#    148,
#    134,
#    120,
#    14,
#    46,
#    70,
#    142,
#    121,
#    12,
#    130,
#    74,
#    70,
#    166,
#    77,
#    117,
#    85,
#    62,
#    124,
#    150,
#    14,
#    149,
#    100,
#    28,
#    27,
#    108,
#    79,
#    129,
#    92,
#    139,
#    108,
#    88,
#    37,
#    35,
#    21,
#    55,
#    125,
#    73,
#    138,
#    171,
#    14,
#    29,
#    117,
#    152,
#    27,
#    14,
#    130,
#    19,
#    117,
#    14,
#    103],
#   [19,
#    36,
#    32,
#    29,
#    29,
#    32,
#    30,
#    9,
#    6,
#    25,
#    26,
#    34,
#    4,
#    49,
#    17,
#    50,
#    32,
#    55,
#    58,
#    26,
#    30,
#    29,
#    43,
#    8,
#    17,
#    26,
#    37,
#    42,
#    27,
#    35,
#    43,
#    25,
#    53,
#    7,
#    12,
#    25,
#    34,
#    3,
#    56,
#    46,
#    34,
#    26,
#    37,
#    54,
#    14,
#    25,
#    17,
#    8,
#    54,
#    32,
#    43,
#    49,
#    7,
#    34,
#    10,
#    7,
#    29,
#    29,
#    21],
#   [],
#   [49,
#    4,
#    7,
#    52,
#    50,
#    4,
#    25,
#    2,
#    25,
#    51,
#    14,
#    43,
#    45,
#    28,
#    5,
#    7,
#    18,
#    13,
#    4,
#    32,
#    25,
#    28,
#    27,
#    29,
#    32,
#    28,
#    29,
#    32,
#    28,
#    51,
#    45,
#    7,
#    27,
#    14,
#    25,
#    2,
#    28,
#    32,
#    41,
#    4,
#    37,
#    37,
#    2,
#    13,
#    4,
#    24,
#    28,
#    50,
#    38,
#    43,
#    42,
#    45,
#    7,
#    14],
#   [3, 2, 3, 1],
#   [34,
#    14,
#    63,
#    50,
#    84,
#    26,
#    18,
#    77,
#    73,
#    64,
#    27,
#    30,
#    63,
#    42,
#    22,
#    46,
#    1,
#    3,
#    12,
#    69,
#    27,
#    71,
#    5,
#    33,
#    26,
#    40,
#    56,
#    40,
#    26,
#    18,
#    84,
#    61,
#    34,
#    3,
#    49,
#    63,
#    30,
#    71,
#    18,
#    27,
#    61,
#    22,
#    63,
#    61,
#    18,
#    14,
#    67,
#    51,
#    33,
#    34,
#    15,
#    84,
#    22,
#    27,
#    69,
#    51,
#    84,
#    23,
#    27,
#    40,
#    56,
#    42,
#    41,
#    12,
#    69,
#    27,
#    71,
#    28,
#    7,
#    1,
#    51,
#    59,
#    26,
#    18,
#    84,
#    73,
#    27,
#    21,
#    27,
#    4,
#    29,
#    27,
#    56,
#    52,
#    11],
#   [1, 1],
#   [22,
#    18,
#    16,
#    13,
#    22,
#    13,
#    24,
#    13,
#    12,
#    6,
#    5,
#    3,
#    13,
#    14,
#    7,
#    24,
#    12,
#    9,
#    13,
#    16,
#    2,
#    4,
#    23,
#    13,
#    12,
#    13],
#   [],
#   [11,
#    21,
#    36,
#    27,
#    14,
#    8,
#    44,
#    13,
#    24,
#    45,
#    32,
#    10,
#    5,
#    12,
#    31,
#    35,
#    15,
#    12,
#    27,
#    43,
#    22,
#    28,
#    29,
#    14,
#    27,
#    8,
#    19,
#    10,
#    5,
#    8,
#    36,
#    46,
#    9,
#    46,
#    23,
#    38,
#    24,
#    37,
#    8,
#    33,
#    25,
#    27,
#    2,
#    8,
#    44,
#    27,
#    17],
#   [2, 1, 1],
#   [7, 8, 4, 5, 2, 14, 7, 12, 9, 14, 18, 7, 2, 8, 16, 19, 9, 19, 16, 7, 15]],
#  'padded_context': array([[ 24,  31,  43, ...,   0,   0,   0],
#         [ 14, 154, 117, ..., 117,  14, 103],
#         [ 19,  36,  32, ...,   0,   0,   0],
#         ...,
#         [ 11,  21,  36, ...,   0,   0,   0],
#         [  2,   1,   1, ...,   0,   0,   0],
#         [  7,   8,   4, ...,   0,   0,   0]], dtype=int32),
#  'targets': array([[ 31,  43,  38, ...,   0,   0,   0],
#         [154, 117, 137, ...,  14, 103,   0],
#         [ 36,  32,  29, ...,   0,   0,   0],
#         ...,
#         [ 21,  36,  27, ...,   0,   0,   0],
#         [  1,   1,   0, ...,   0,   0,   0],
#         [  8,   4,   5, ...,   0,   0,   0]]),
#  'vocab_size': 178}

# %%
model.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/3r/hfw5ds7x10s2p6ps2ct8m4j40000gn/T/ipykernel_55404/1548584363.py in <module>
# ----> 1 model.predict()
#
# TypeError: predict() missing 1 required positional argument: 'x'

# %%
cont = []
targ = []
for ctx in context:
    for cx in ctx:
        cont.append(cx)
        targ.append(np.argmax(pred[cx]))
df = pd.DataFrame({'Word':cont, 'Next Predicted Word':targ})

# %%
df
